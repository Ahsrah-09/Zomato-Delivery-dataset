# %%
import numpy as np;
import pandas as pd;
from pandas import DataFrame

# %%
data=pd.read_csv("/content/zomato.csv",encoding="latin1")

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
data.shape
# Out:
# (9551, 21)

# %%
data.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
# Deleting unnecessary columns from the data

cols_to_del = [ 'Country Code', 'Address',
       'Locality', 'Locality Verbose', 'Longitude', 'Latitude' ,'Switch to order menu', 'Rating color' ]

data = data.drop(cols_to_del, axis = 1 )
data.head()
# Out:
#    Restaurant ID         Restaurant Name              City  \
# 0        6317637        Le Petit Souffle       Makati City
# 1        6304287        Izakaya Kikufuji       Makati City
# 2        6300002  Heat - Edsa Shangri-La  Mandaluyong City
# 3        6318506                    Ooma  Mandaluyong City
# 4        6314302             Sambo Kojin  Mandaluyong City
#
#                            Cuisines  Average Cost for two          Currency  \
# 0        French, Japanese, Desserts                  1100  Botswana Pula(P)
# 1                          Japanese                  1200  Botswana Pula(P)
# 2  Seafood, Asian, Filipino, Indian                  4000  Botswana Pula(P)
# 3                   Japanese, Sushi                  1500  Botswana Pula(P)
# 4                  Japanese, Korean                  1500  Botswana Pula(P)
#
#   Has Table booking Has Online delivery Is delivering now  Price range  \
# 0               Yes                  No                No            3
# ...

# %%
data.shape
# Out:
# (9551, 13)

# %%
data["Rating text"].value_counts()
# Out:
# Rating text
# Average      3737
# Not rated    2148
# Good         2100
# Very Good    1079
# Excellent     301
# Poor          186
# Name: count, dtype: int64

# %%
data["Rating text"].value_counts(normalize=True)*100
# Out:
# Rating text
# Average      39.126793
# Not rated    22.489792
# Good         21.987226
# Very Good    11.297246
# Excellent     3.151502
# Poor          1.947440
# Name: proportion, dtype: float64

# %% [markdown]
# **Observations**
#
# Lot of Restaurants have been rated as avg (39.12%) only 3.15% of restaurants as Excellent

# %%
data[data["Aggregate rating"]>=4]
# Out:
#       Restaurant ID           Restaurant Name              City  \
# 0           6317637          Le Petit Souffle       Makati City
# 1           6304287          Izakaya Kikufuji       Makati City
# 2           6300002    Heat - Edsa Shangri-La  Mandaluyong City
# 3           6318506                      Ooma  Mandaluyong City
# 4           6314302               Sambo Kojin  Mandaluyong City
# ...             ...                       ...               ...
# 9545        5915054                  Baltazar         ÛÁstanbul
# 9546        5915730              NamlÛ± Gurme         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±         ÛÁstanbul
# 9549        5916112              Aôôk Kahve         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery         ÛÁstanbul
#
#                               Cuisines  Average Cost for two  \
# 0           French, Japanese, Desserts                  1100
# 1                             Japanese                  1200
# ...

# %%
data[["Restaurant Name","Cuisines"]]
# Out:
#                Restaurant Name                          Cuisines
# 0             Le Petit Souffle        French, Japanese, Desserts
# 1             Izakaya Kikufuji                          Japanese
# 2       Heat - Edsa Shangri-La  Seafood, Asian, Filipino, Indian
# 3                         Ooma                   Japanese, Sushi
# 4                  Sambo Kojin                  Japanese, Korean
# ...                        ...                               ...
# 9546              NamlÛ± Gurme                           Turkish
# 9547             Ceviz AÛôacÛ±   World Cuisine, Patisserie, Cafe
# 9548                     Huqqa            Italian, World Cuisine
# 9549              Aôôk Kahve                   Restaurant Cafe
# 9550  Walter's Coffee Roastery                              Cafe
#
# [9551 rows x 2 columns]

# %%
data["Currency"].unique()
# Out:
# array(['Botswana Pula(P)', 'Brazilian Real(R$)', 'Dollar($)',
#        'Emirati Diram(AED)', 'Indian Rupees(Rs.)',
#        'Indonesian Rupiah(IDR)', 'NewZealand($)', 'Pounds(\x8c£)',
#        'Qatari Rial(QR)', 'Rand(R)', 'Sri Lankan Rupee(LKR)',
#        'Turkish Lira(TL)'], dtype=object)

# %%
data[data["Currency"]=="Indian Rupees(Rs.)"]
# Out:
#       Restaurant ID                        Restaurant Name   City  \
# 624         3400025                             Jahanpanah   Agra
# 625         3400341                    Rangrezz Restaurant   Agra
# 626         3400005                Time2Eat - Mama Chicken   Agra
# 627         3400021  Chokho Jeeman Marwari Jain Bhojanalya   Agra
# 628         3400017                         Pinch Of Spice   Agra
# ...             ...                                    ...    ...
# 9271        2800100                               D Cabana  Vizag
# 9272        2800418                               Kaloreez  Vizag
# 9273        2800881                                Plot 17  Vizag
# 9274        2800042                       Vista - The Park  Vizag
# 9275        2800019               Flying Spaghetti Monster  Vizag
#
#                                                Cuisines  Average Cost for two  \
# 624                               North Indian, Mughlai                   850
# ...

# %%
data[(data["Currency"] == "Indian Rupees(Rs.)") & (data["City"] == "Vizag")]
# Out:
#       Restaurant ID             Restaurant Name   City  \
# 9256        2800013                   Pizza Hut  Vizag
# 9257        2800012                   Pizza Hut  Vizag
# 9258        2800294          Sri Sairam Parlour  Vizag
# 9259        2800903    Mekong - Hotel GreenPark  Vizag
# 9260        2800052  The Square - Hotel Novotel  Vizag
# 9261        2800095                 Alpha Hotel  Vizag
# 9262        2800856             Barbeque Nation  Vizag
# 9263        2800911                 Double Roti  Vizag
# 9264        2800757                Bake My Wish  Vizag
# 9265        2800096            Kamat Restaurant  Vizag
# 9266        2800083               My Restaurant  Vizag
# 9267       18306045     Percolator Coffee House  Vizag
# 9268        2800897                  Tea Trails  Vizag
# 9269       18285610                 Six Degrees  Vizag
# 9270        2800128  Sea Inn - Raju Gaari Dhaba  Vizag
# 9271        2800100                    D Cabana  Vizag
# ...
